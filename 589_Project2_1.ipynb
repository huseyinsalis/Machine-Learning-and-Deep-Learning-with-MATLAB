# %%
import tensorflow as tf
from tensorflow import keras
from datetime import datetime
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.callbacks import TensorBoard
import os

model = Sequential()
model.add(Flatten(input_shape=[28, 28]))
model.add(Dense(300, activation="relu"))
model.add(Dense(100, activation="relu"))
model.add(Dense(10, activation="softmax"))

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255

model.compile(loss="sparse_categorical_crossentropy",
              optimizer="sgd",
              metrics=["accuracy"])


root_logdir = os.path.join(os.curdir, "589logs")

def get_run_logdir():
    import time
    run_id = time.strftime("f_mnist_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)

log_dir = get_run_logdir()


tensorb = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_grads=False, write_images=False, embeddings_freq=0, embeddings_layer_names=None, embeddings_metadata=None, embeddings_data=None, update_freq='epoch',profile_batch = 100000000)

callbacks = [
    tensorb,
    keras.callbacks.EarlyStopping(patience=10,
                                    restore_best_weights=True)
]

history = model.fit(train_images, train_labels, epochs=100,
                    validation_data=(test_images, test_labels),
                    callbacks=callbacks)
model.save("f_minst.h5")
scores = model.evaluate(test_images, test_labels, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 6s 98us/sample - loss: 0.5843 - accuracy: 0.8465 - val_loss: 0.3105 - val_accuracy: 0.9123
# Epoch 2/100
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.2838 - accuracy: 0.9194 - val_loss: 0.2463 - val_accuracy: 0.9275
# Epoch 3/100
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.2301 - accuracy: 0.9347 - val_loss: 0.2046 - val_accuracy: 0.9403
# Epoch 4/100
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.1948 - accuracy: 0.9443 - val_loss: 0.1782 - val_accuracy: 0.9469
# Epoch 5/100
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.1694 - accuracy: 0.9519 - val_loss: 0.1592 - val_accuracy: 0.9538
# Epoch 6/100
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.1496 - accuracy: 0.9573 - val_loss: 0.1426 - val_accuracy: 0.9574
# Epoch 7/100
# 60000/60000 [==============================] - 8s 139us/sample - loss: 0.1340 - accuracy: 0.9621 - val_loss: 0.1339 - val_accuracy: 0.9601
# Epoch 8/100
# 60000/60000 [==============================] - 9s 158us/sample - loss: 0.1215 - accuracy: 0.9653 - val_loss: 0.1196 - val_accuracy: 0.9641
# Epoch 9/100
# 60000/60000 [==============================] - 7s 114us/sample - loss: 0.1104 - accuracy: 0.9685 - val_loss: 0.1145 - val_accuracy: 0.9649
# Epoch 10/100
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.1005 - accuracy: 0.9714 - val_loss: 0.1059 - val_accuracy: 0.9670
# Epoch 11/100
# 60000/60000 [==============================] - 9s 158us/sample - loss: 0.0927 - accuracy: 0.9740 - val_loss: 0.1022 - val_accuracy: 0.9696
# Epoch 12/100
# 60000/60000 [==============================] - 11s 178us/sample - loss: 0.0856 - accuracy: 0.9760 - val_loss: 0.0982 - val_accuracy: 0.9699
# Epoch 13/100
# 60000/60000 [==============================] - 9s 148us/sample - loss: 0.0790 - accuracy: 0.9778 - val_loss: 0.0930 - val_accuracy: 0.9714
# Epoch 14/100
# 60000/60000 [==============================] - 8s 134us/sample - loss: 0.0734 - accuracy: 0.9796 - val_loss: 0.0888 - val_accuracy: 0.9739
# Epoch 15/100
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.0685 - accuracy: 0.9814 - val_loss: 0.0850 - val_accuracy: 0.9740
# Epoch 16/100
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.0640 - accuracy: 0.9826 - val_loss: 0.0828 - val_accuracy: 0.9751
# Epoch 17/100
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.0598 - accuracy: 0.9836 - val_loss: 0.0816 - val_accuracy: 0.9744
# Epoch 18/100
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.0564 - accuracy: 0.9847 - val_loss: 0.0781 - val_accuracy: 0.9760
# Epoch 19/100
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.0529 - accuracy: 0.9858 - val_loss: 0.0785 - val_accuracy: 0.9756
# Epoch 20/100
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.0494 - accuracy: 0.9871 - val_loss: 0.0772 - val_accuracy: 0.9756
# Epoch 21/100
# 60000/60000 [==============================] - 6s 100us/sample - loss: 0.0468 - accuracy: 0.9874 - val_loss: 0.0752 - val_accuracy: 0.9763
# Epoch 22/100
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.0439 - accuracy: 0.9885 - val_loss: 0.0763 - val_accuracy: 0.9763
# Epoch 23/100
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.0414 - accuracy: 0.9894 - val_loss: 0.0721 - val_accuracy: 0.9771
# Epoch 24/100
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.0393 - accuracy: 0.9898 - val_loss: 0.0725 - val_accuracy: 0.9773
# Epoch 25/100
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.0370 - accuracy: 0.9907 - val_loss: 0.0704 - val_accuracy: 0.9783
# Epoch 26/100
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.0348 - accuracy: 0.9914 - val_loss: 0.0733 - val_accuracy: 0.9756
# Epoch 27/100
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.0330 - accuracy: 0.9922 - val_loss: 0.0708 - val_accuracy: 0.9763
# Epoch 28/100
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.0313 - accuracy: 0.9926 - val_loss: 0.0695 - val_accuracy: 0.9782
# Epoch 29/100
# 60000/60000 [==============================] - 7s 112us/sample - loss: 0.0297 - accuracy: 0.9929 - val_loss: 0.0680 - val_accuracy: 0.9787
# Epoch 30/100
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.0279 - accuracy: 0.9936 - val_loss: 0.0688 - val_accuracy: 0.9784
# Epoch 31/100
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.0266 - accuracy: 0.9942 - val_loss: 0.0679 - val_accuracy: 0.9784
# Epoch 32/100
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.0253 - accuracy: 0.9945 - val_loss: 0.0661 - val_accuracy: 0.9792
# Epoch 33/100
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.0239 - accuracy: 0.9949 - val_loss: 0.0669 - val_accuracy: 0.9790
# Epoch 34/100
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.0226 - accuracy: 0.9951 - val_loss: 0.0658 - val_accuracy: 0.9796
# Epoch 35/100
# 60000/60000 [==============================] - 7s 112us/sample - loss: 0.0214 - accuracy: 0.9960 - val_loss: 0.0687 - val_accuracy: 0.9788
# Epoch 36/100
# 60000/60000 [==============================] - 8s 136us/sample - loss: 0.0205 - accuracy: 0.9957 - val_loss: 0.0671 - val_accuracy: 0.9790
# Epoch 37/100
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.0193 - accuracy: 0.9965 - val_loss: 0.0661 - val_accuracy: 0.9789
# Epoch 38/100
# 60000/60000 [==============================] - 5s 90us/sample - loss: 0.0183 - accuracy: 0.9968 - val_loss: 0.0660 - val_accuracy: 0.9788
# Epoch 39/100
# 60000/60000 [==============================] - 7s 115us/sample - loss: 0.0175 - accuracy: 0.9970 - val_loss: 0.0655 - val_accuracy: 0.9796
# Epoch 40/100
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.0166 - accuracy: 0.9972 - val_loss: 0.0674 - val_accuracy: 0.9785
# Epoch 41/100
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.0157 - accuracy: 0.9977 - val_loss: 0.0656 - val_accuracy: 0.9796
# Epoch 42/100
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.0150 - accuracy: 0.9978 - val_loss: 0.0661 - val_accuracy: 0.9797
# Epoch 43/100
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.0143 - accuracy: 0.9980 - val_loss: 0.0657 - val_accuracy: 0.9801
# Epoch 44/100
# 60000/60000 [==============================] - 6s 92us/sample - loss: 0.0135 - accuracy: 0.9981 - val_loss: 0.0658 - val_accuracy: 0.9797
# Epoch 45/100
# 60000/60000 [==============================] - 6s 97us/sample - loss: 0.0129 - accuracy: 0.9984 - val_loss: 0.0668 - val_accuracy: 0.9791
# Epoch 46/100
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.0124 - accuracy: 0.9984 - val_loss: 0.0663 - val_accuracy: 0.9794
# Epoch 47/100
# 60000/60000 [==============================] - 7s 113us/sample - loss: 0.0119 - accuracy: 0.9984 - val_loss: 0.0663 - val_accuracy: 0.9795
# Epoch 48/100
# 60000/60000 [==============================] - 8s 129us/sample - loss: 0.0112 - accuracy: 0.9987 - val_loss: 0.0669 - val_accuracy: 0.9794
# Epoch 49/100
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.0108 - accuracy: 0.9988 - val_loss: 0.0669 - val_accuracy: 0.9796
# 10000/10000 [==============================] - 0s 44us/sample - loss: 0.0655 - accuracy: 0.9796
# Test loss: 0.0655015727979131
# Test accuracy: 0.9796

# %%
from __future__ import print_function
import tensorflow as tf
from tensorflow import keras
from datetime import datetime
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint

import os.path

import os

batch_size = 32
num_classes = 10
epochs = 50

model_name = 'cifar-10.h5'

root_logdir = os.path.join(os.curdir, "589logs")

def get_run_logdir():
    import time
    run_id = time.strftime("cifar-10_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)

log_dir = get_run_logdir() 
   
# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same', input_shape=x_train.shape[1:]))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# initiate RMSprop optimizer
opt = keras.optimizers.RMSprop(lr=0.0001, decay=1e-6)

# train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# Normalize the data
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

#Tensorboard parameters
tensorb = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_grads=False, write_images=False, embeddings_freq=0, embeddings_layer_names=None, embeddings_metadata=None, embeddings_data=None, update_freq='epoch',profile_batch = 100000000)

model.save(model_name)
print('Saved trained model at %s ' % model_name)

#Checkpoint parameters save best model in case of overfitting
checkpoint = ModelCheckpoint(model_name, verbose=1, save_best_only=True)
if os.path.exists(model_name): model = load_model(model_name)
    
model.fit(x_train, y_train,
        batch_size=batch_size,
        epochs=epochs,
        validation_data=(x_test, y_test),
        shuffle=True,
        callbacks=[tensorb,checkpoint])


# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Saved trained model at cifar-10.h5
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 1.9973 - accuracy: 0.2342
# Epoch 00001: val_loss improved from inf to 1.69460, saving model to cifar-10.h5
# 50000/50000 [==============================] - 175s 4ms/sample - loss: 1.9972 - accuracy: 0.2343 - val_loss: 1.6946 - val_accuracy: 0.3788
# Epoch 2/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 1.6908 - accuracy: 0.3703
# Epoch 00002: val_loss improved from 1.69460 to 1.49491, saving model to cifar-10.h5
# 50000/50000 [==============================] - 167s 3ms/sample - loss: 1.6908 - accuracy: 0.3703 - val_loss: 1.4949 - val_accuracy: 0.4517
# Epoch 3/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 1.5223 - accuracy: 0.4415
# Epoch 00003: val_loss improved from 1.49491 to 1.40998, saving model to cifar-10.h5
# 50000/50000 [==============================] - 166s 3ms/sample - loss: 1.5223 - accuracy: 0.4415 - val_loss: 1.4100 - val_accuracy: 0.4850
# Epoch 4/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 1.4077 - accuracy: 0.4931
# Epoch 00004: val_loss improved from 1.40998 to 1.30554, saving model to cifar-10.h5
# 50000/50000 [==============================] - 166s 3ms/sample - loss: 1.4077 - accuracy: 0.4931 - val_loss: 1.3055 - val_accuracy: 0.5282
# Epoch 5/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 1.3229 - accuracy: 0.5245
# Epoch 00005: val_loss improved from 1.30554 to 1.22444, saving model to cifar-10.h5
# 50000/50000 [==============================] - 169s 3ms/sample - loss: 1.3231 - accuracy: 0.5244 - val_loss: 1.2244 - val_accuracy: 0.5536
# Epoch 6/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 1.2598 - accuracy: 0.5505
# Epoch 00006: val_loss improved from 1.22444 to 1.14374, saving model to cifar-10.h5
# 50000/50000 [==============================] - 161s 3ms/sample - loss: 1.2598 - accuracy: 0.5505 - val_loss: 1.1437 - val_accuracy: 0.5842
# Epoch 7/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 1.1937 - accuracy: 0.5774
# Epoch 00007: val_loss did not improve from 1.14374
# 50000/50000 [==============================] - 160s 3ms/sample - loss: 1.1938 - accuracy: 0.5774 - val_loss: 1.1907 - val_accuracy: 0.5795
# Epoch 8/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 1.1452 - accuracy: 0.5960
# Epoch 00008: val_loss improved from 1.14374 to 1.07454, saving model to cifar-10.h5
# 50000/50000 [==============================] - 164s 3ms/sample - loss: 1.1451 - accuracy: 0.5960 - val_loss: 1.0745 - val_accuracy: 0.6242
# Epoch 9/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 1.0983 - accuracy: 0.6168
# Epoch 00009: val_loss improved from 1.07454 to 1.00029, saving model to cifar-10.h5
# 50000/50000 [==============================] - 162s 3ms/sample - loss: 1.0982 - accuracy: 0.6169 - val_loss: 1.0003 - val_accuracy: 0.6442
# Epoch 10/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 1.0579 - accuracy: 0.6313
# Epoch 00010: val_loss did not improve from 1.00029
# 50000/50000 [==============================] - 167s 3ms/sample - loss: 1.0578 - accuracy: 0.6314 - val_loss: 1.0272 - val_accuracy: 0.6401
# Epoch 11/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 1.0158 - accuracy: 0.6434
# Epoch 00011: val_loss improved from 1.00029 to 0.93928, saving model to cifar-10.h5
# 50000/50000 [==============================] - 170s 3ms/sample - loss: 1.0159 - accuracy: 0.6434 - val_loss: 0.9393 - val_accuracy: 0.6693
# Epoch 12/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.9816 - accuracy: 0.6577
# Epoch 00012: val_loss improved from 0.93928 to 0.92164, saving model to cifar-10.h5
# 50000/50000 [==============================] - 162s 3ms/sample - loss: 0.9817 - accuracy: 0.6577 - val_loss: 0.9216 - val_accuracy: 0.6747
# Epoch 13/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.9497 - accuracy: 0.6699
# Epoch 00013: val_loss improved from 0.92164 to 0.88098, saving model to cifar-10.h5
# 50000/50000 [==============================] - 161s 3ms/sample - loss: 0.9496 - accuracy: 0.6699 - val_loss: 0.8810 - val_accuracy: 0.6899
# Epoch 14/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.9211 - accuracy: 0.6815
# Epoch 00014: val_loss improved from 0.88098 to 0.84491, saving model to cifar-10.h5
# 50000/50000 [==============================] - 161s 3ms/sample - loss: 0.9211 - accuracy: 0.6815 - val_loss: 0.8449 - val_accuracy: 0.7021
# Epoch 15/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.8988 - accuracy: 0.6886
# Epoch 00015: val_loss improved from 0.84491 to 0.83481, saving model to cifar-10.h5
# 50000/50000 [==============================] - 161s 3ms/sample - loss: 0.8988 - accuracy: 0.6886 - val_loss: 0.8348 - val_accuracy: 0.7087
# Epoch 16/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.8665 - accuracy: 0.7005 ETA: 1s - l
# Epoch 00016: val_loss improved from 0.83481 to 0.82836, saving model to cifar-10.h5
# 50000/50000 [==============================] - 165s 3ms/sample - loss: 0.8665 - accuracy: 0.7005 - val_loss: 0.8284 - val_accuracy: 0.7150
# Epoch 17/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.8486 - accuracy: 0.7075
# Epoch 00017: val_loss did not improve from 0.82836
# 50000/50000 [==============================] - 161s 3ms/sample - loss: 0.8485 - accuracy: 0.7075 - val_loss: 0.8735 - val_accuracy: 0.7047
# Epoch 18/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.8240 - accuracy: 0.7178
# Epoch 00018: val_loss improved from 0.82836 to 0.76475, saving model to cifar-10.h5
# 50000/50000 [==============================] - 161s 3ms/sample - loss: 0.8239 - accuracy: 0.7179 - val_loss: 0.7647 - val_accuracy: 0.7359
# Epoch 19/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.8068 - accuracy: 0.7232
# Epoch 00019: val_loss did not improve from 0.76475
# 50000/50000 [==============================] - 163s 3ms/sample - loss: 0.8068 - accuracy: 0.7232 - val_loss: 0.8330 - val_accuracy: 0.7163
# Epoch 20/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.7871 - accuracy: 0.7295
# Epoch 00020: val_loss did not improve from 0.76475
# 50000/50000 [==============================] - 162s 3ms/sample - loss: 0.7871 - accuracy: 0.7295 - val_loss: 0.7957 - val_accuracy: 0.7253
# Epoch 21/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.7736 - accuracy: 0.7356
# Epoch 00021: val_loss improved from 0.76475 to 0.74115, saving model to cifar-10.h5
# 50000/50000 [==============================] - 160s 3ms/sample - loss: 0.7736 - accuracy: 0.7356 - val_loss: 0.7411 - val_accuracy: 0.7483
# Epoch 22/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.7554 - accuracy: 0.7433
# Epoch 00022: val_loss improved from 0.74115 to 0.72807, saving model to cifar-10.h5
# 50000/50000 [==============================] - 160s 3ms/sample - loss: 0.7555 - accuracy: 0.7433 - val_loss: 0.7281 - val_accuracy: 0.7528
# Epoch 23/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.7454 - accuracy: 0.7474
# Epoch 00023: val_loss did not improve from 0.72807
# 50000/50000 [==============================] - 162s 3ms/sample - loss: 0.7454 - accuracy: 0.7475 - val_loss: 0.7341 - val_accuracy: 0.7511
# Epoch 24/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.7297 - accuracy: 0.7521
# Epoch 00024: val_loss did not improve from 0.72807
# 50000/50000 [==============================] - 162s 3ms/sample - loss: 0.7298 - accuracy: 0.7520 - val_loss: 0.7336 - val_accuracy: 0.7498
# Epoch 25/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.7192 - accuracy: 0.7574
# Epoch 00025: val_loss did not improve from 0.72807
# 50000/50000 [==============================] - 165s 3ms/sample - loss: 0.7192 - accuracy: 0.7574 - val_loss: 0.7504 - val_accuracy: 0.7480
# Epoch 26/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.7110 - accuracy: 0.7609
# Epoch 00026: val_loss improved from 0.72807 to 0.72340, saving model to cifar-10.h5
# 50000/50000 [==============================] - 164s 3ms/sample - loss: 0.7110 - accuracy: 0.7608 - val_loss: 0.7234 - val_accuracy: 0.7572
# Epoch 27/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6965 - accuracy: 0.7633
# Epoch 00027: val_loss improved from 0.72340 to 0.71246, saving model to cifar-10.h5
# 50000/50000 [==============================] - 166s 3ms/sample - loss: 0.6964 - accuracy: 0.7634 - val_loss: 0.7125 - val_accuracy: 0.7574
# Epoch 28/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6875 - accuracy: 0.7684
# Epoch 00028: val_loss improved from 0.71246 to 0.69203, saving model to cifar-10.h5
# 50000/50000 [==============================] - 152s 3ms/sample - loss: 0.6874 - accuracy: 0.7684 - val_loss: 0.6920 - val_accuracy: 0.7693
# Epoch 29/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6776 - accuracy: 0.7709
# Epoch 00029: val_loss did not improve from 0.69203
# 50000/50000 [==============================] - 151s 3ms/sample - loss: 0.6777 - accuracy: 0.7708 - val_loss: 0.6983 - val_accuracy: 0.7645
# Epoch 30/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6789 - accuracy: 0.7746
# Epoch 00030: val_loss did not improve from 0.69203
# 50000/50000 [==============================] - 153s 3ms/sample - loss: 0.6791 - accuracy: 0.7746 - val_loss: 0.7262 - val_accuracy: 0.7591
# Epoch 31/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6696 - accuracy: 0.7753
# Epoch 00031: val_loss did not improve from 0.69203
# 50000/50000 [==============================] - 157s 3ms/sample - loss: 0.6696 - accuracy: 0.7753 - val_loss: 0.7142 - val_accuracy: 0.7629
# Epoch 32/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6580 - accuracy: 0.7785
# Epoch 00032: val_loss did not improve from 0.69203
# 50000/50000 [==============================] - 155s 3ms/sample - loss: 0.6580 - accuracy: 0.7785 - val_loss: 0.7027 - val_accuracy: 0.7655
# Epoch 33/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6530 - accuracy: 0.7824
# Epoch 00033: val_loss did not improve from 0.69203
# 50000/50000 [==============================] - 156s 3ms/sample - loss: 0.6531 - accuracy: 0.7823 - val_loss: 0.6984 - val_accuracy: 0.7729
# Epoch 34/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6441 - accuracy: 0.7846
# Epoch 00034: val_loss did not improve from 0.69203
# 50000/50000 [==============================] - 157s 3ms/sample - loss: 0.6442 - accuracy: 0.7845 - val_loss: 0.7088 - val_accuracy: 0.7683
# Epoch 35/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6433 - accuracy: 0.7850
# Epoch 00035: val_loss did not improve from 0.69203
# 50000/50000 [==============================] - 165s 3ms/sample - loss: 0.6432 - accuracy: 0.7850 - val_loss: 0.7040 - val_accuracy: 0.7689
# Epoch 36/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6353 - accuracy: 0.7868 ETA: 1s - loss: 0
# Epoch 00036: val_loss improved from 0.69203 to 0.67526, saving model to cifar-10.h5
# 50000/50000 [==============================] - 169s 3ms/sample - loss: 0.6353 - accuracy: 0.7867 - val_loss: 0.6753 - val_accuracy: 0.7757
# Epoch 37/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6356 - accuracy: 0.7898
# Epoch 00037: val_loss did not improve from 0.67526
# 50000/50000 [==============================] - 153s 3ms/sample - loss: 0.6355 - accuracy: 0.7899 - val_loss: 0.6925 - val_accuracy: 0.7692
# Epoch 38/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6283 - accuracy: 0.7919
# Epoch 00038: val_loss improved from 0.67526 to 0.67192, saving model to cifar-10.h5
# 50000/50000 [==============================] - 157s 3ms/sample - loss: 0.6283 - accuracy: 0.7919 - val_loss: 0.6719 - val_accuracy: 0.7820
# Epoch 39/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6233 - accuracy: 0.7936
# Epoch 00039: val_loss did not improve from 0.67192
# 50000/50000 [==============================] - 165s 3ms/sample - loss: 0.6232 - accuracy: 0.7937 - val_loss: 0.6992 - val_accuracy: 0.7710
# Epoch 40/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6186 - accuracy: 0.7944
# Epoch 00040: val_loss did not improve from 0.67192
# 50000/50000 [==============================] - 157s 3ms/sample - loss: 0.6186 - accuracy: 0.7944 - val_loss: 0.6723 - val_accuracy: 0.7849
# Epoch 41/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6250 - accuracy: 0.7932
# Epoch 00041: val_loss did not improve from 0.67192
# 50000/50000 [==============================] - 156s 3ms/sample - loss: 0.6250 - accuracy: 0.7932 - val_loss: 0.6803 - val_accuracy: 0.7747
# Epoch 42/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6101 - accuracy: 0.7980
# Epoch 00042: val_loss improved from 0.67192 to 0.67029, saving model to cifar-10.h5
# 50000/50000 [==============================] - 162s 3ms/sample - loss: 0.6100 - accuracy: 0.7980 - val_loss: 0.6703 - val_accuracy: 0.7787
# Epoch 43/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6132 - accuracy: 0.7969
# Epoch 00043: val_loss did not improve from 0.67029
# 50000/50000 [==============================] - 161s 3ms/sample - loss: 0.6132 - accuracy: 0.7969 - val_loss: 0.6846 - val_accuracy: 0.7763
# Epoch 44/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6055 - accuracy: 0.8009
# Epoch 00044: val_loss did not improve from 0.67029
# 50000/50000 [==============================] - 161s 3ms/sample - loss: 0.6054 - accuracy: 0.8010 - val_loss: 0.6898 - val_accuracy: 0.7744
# Epoch 45/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6061 - accuracy: 0.7997
# Epoch 00045: val_loss did not improve from 0.67029
# 50000/50000 [==============================] - 161s 3ms/sample - loss: 0.6061 - accuracy: 0.7997 - val_loss: 0.6753 - val_accuracy: 0.7741
# Epoch 46/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6062 - accuracy: 0.8013
# Epoch 00046: val_loss did not improve from 0.67029
# 50000/50000 [==============================] - 162s 3ms/sample - loss: 0.6064 - accuracy: 0.8013 - val_loss: 0.6967 - val_accuracy: 0.7748
# Epoch 47/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6005 - accuracy: 0.8015
# Epoch 00047: val_loss did not improve from 0.67029
# 50000/50000 [==============================] - 161s 3ms/sample - loss: 0.6004 - accuracy: 0.8015 - val_loss: 0.6873 - val_accuracy: 0.7756
# Epoch 48/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6040 - accuracy: 0.8020
# Epoch 00048: val_loss did not improve from 0.67029
# 50000/50000 [==============================] - 161s 3ms/sample - loss: 0.6040 - accuracy: 0.8020 - val_loss: 0.6815 - val_accuracy: 0.7809
# Epoch 49/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6010 - accuracy: 0.8009
# Epoch 00049: val_loss did not improve from 0.67029
# 50000/50000 [==============================] - 165s 3ms/sample - loss: 0.6011 - accuracy: 0.8009 - val_loss: 0.7272 - val_accuracy: 0.7678
# Epoch 50/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.6002 - accuracy: 0.8052
# Epoch 00050: val_loss did not improve from 0.67029
# 50000/50000 [==============================] - 164s 3ms/sample - loss: 0.6003 - accuracy: 0.8051 - val_loss: 0.6909 - val_accuracy: 0.7767
# 10000/10000 [==============================] - 6s 626us/sample - loss: 0.6909 - accuracy: 0.7767
# Test loss: 0.6909212416648864
# Test accuracy: 0.7767
